# %%
from gnews import GNews

# %%
google_news = GNews(language='en', country='India', start_date=(2024,4,3), end_date=(2024,4,5))
reliance_news = google_news.get_news('Reliance Industries Ltd')

# %%
reliance_news
# Out:
# [{'title': 'Reliance Industries falls Thursday, underperforms market - MarketWatch',
#   'description': 'Reliance Industries falls Thursday, underperforms market  MarketWatch',
#   'published date': 'Thu, 04 Apr 2024 10:30:00 GMT',
#   'url': 'https://news.google.?oc=5&hl=en-IN&gl=IN&ceid=IN:en',
#   'publisher': {'href': 'https://www.marketwatch.com',
#    'title': 'MarketWatch'}},
#  {'title': "Reliance Industries share price Today Live Updates : Reliance Industries closed today at ₹2942.4, down -0.97% from yesterday's ₹2971.3 | Mint - Mint",
# ...

# %%
reliance_news2 = google_news.get_news('RIL')
reliance_news2
# Out:
# [{'title': 'ABQ BioPark hosting its “Great Ape-ril” events - KRQE News 13',
#   'description': 'ABQ BioPark hosting its “Great Ape-ril” events  KRQE News 13',
#   'published date': 'Wed, 03 Apr 2024 17:21:18 GMT',
#   'url': 'https://news.google.com/rss/articles/CBMiUWh0dHBzOi8vd3d3LmtycWUuY29tL25ld3MvY29tbXVuaXR5L2FicS1iaW9wYXJrLWhvc3RpbmctaXRzLWdyZWF0LWFwZS1yaWwtZXZlbnRzL9IBVWh0dHBzOi8vd3d3LmtycWUuY29tL25ld3MvY29tbXVuaXR5L2FicS1iaW9wYXJrLWhvc3RpbmctaXRzLWdyZWF0LWFwZS1yaWwtZXZlbnRzL2FtcC8?oc=5&hl=en-IN&gl=IN&ceid=IN:en',
#   'publisher': {'href': 'https://www.krqe.com', 'title': 'KRQE News 13'}},
#  {'title': 'ET Exclusive: RIL, Tata Motors and IOC to be key bidders for pilot GH2 project - The Economic Times',
#   'description': 'ET Exclusive: RIL, Tata Motors and IOC to be key bidders for pilot GH2 project  The Economic Times',
#   'published date': 'Wed, 03 Apr 2024 19:19:47 GMT',
#   'url': 'https://news.google....?oc=5&hl=en-IN&gl=IN&ceid=IN:en',
# ...
